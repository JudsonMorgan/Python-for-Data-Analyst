# %% [markdown]
# ***Data dictionary***
#
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# CRIM - per capita crime rate by town
#
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS - proportion of non-retail business acres per town.
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX - nitric oxides concentration (parts per 10 million)
#
# RM - average number of rooms per dwelling
#
# AGE - proportion of owner-occupied units built prior to 1940
#
# DIS - weighted distances to five Boston employment centres
#
# RAD - index of accessibility to radial highways
#
# TAX - full-value property-tax rate per $10,000
#
# PTRATIO - pupil-teacher ratio by town
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT - % lower status of the population
#
# MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Neccessary import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()
# %matplotlib inline
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'data_module', 'feature_names', 'filename', 'target']

# %%
data.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
data.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %% [markdown]
# ### ETL (extract, transform, and load) processes.

# %%
df = pd.DataFrame(data = data.data, columns = data.feature_names)

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#include the target

df['target'] = data.target

#view the data
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
#save the data
df.to_csv('data/house_price.csv', index = False)

# %% [markdown]
# ### Load the data

# %%
house_df = pd.read_csv('data/house_price.csv')
#view the data
house_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ### Exploratory Data analysis (EDA)

# %%
house_df.shape
# Out:
# (506, 14)

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
house_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
house_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# #### Outlier Detection and Removal

# %%
data = house_df.copy()

# %%
sns.boxplot(data = data, x = 'CRIM')
# Out:
# <AxesSubplot:xlabel='CRIM'>

# %%
Q1 = data['CRIM'].quantile(0.25)
Q3 = data['CRIM'].quantile(0.75)
Q1, Q3
# Out:
# (0.08204499999999999, 3.6770825)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 3.5950375

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
lower_limit, upper_limit
# Out:
# (-5.31051125, 9.06963875)

# %%
data[(data['CRIM'] > upper_limit) | (data['CRIM'] < lower_limit)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 367  13.5222  0.0   18.1   0.0  0.631  3.863  100.0  1.5106  24.0  666.0
# 371   9.2323  0.0   18.1   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# 373  11.1081  0.0   18.1   0.0  0.668  4.906  100.0  1.1742  24.0  666.0
# 374  18.4982  0.0   18.1   0.0  0.668  4.138  100.0  1.1370  24.0  666.0
# 375  19.6091  0.0   18.1   0.0  0.671  7.313   97.9  1.3163  24.0  666.0
# ..       ...  ...    ...   ...    ...    ...    ...     ...   ...    ...
# 468  15.5757  0.0   18.1   0.0  0.580  5.926   71.0  2.9084  24.0  666.0
# 469  13.0751  0.0   18.1   0.0  0.580  5.713   56.7  2.8237  24.0  666.0
# 477  15.0234  0.0   18.1   0.0  0.614  5.304   97.3  2.1007  24.0  666.0
# 478  10.2330  0.0   18.1   0.0  0.614  6.185   96.7  2.1705  24.0  666.0
# 479  14.3337  0.0   18.1   0.0  0.614  6.229   88.0  1.9512  24.0  666.0
#
#      PTRATIO       B  LSTAT  target
# 367     20.2  131.42  13.33    23.1
# ...

# %%
data_1 = data[(data['CRIM'] <= upper_limit) & (data['CRIM'] >= lower_limit)]
data_1.shape
# Out:
# (440, 14)

# %%
sns.boxplot(data = data, x = 'ZN')
# Out:
# <AxesSubplot:xlabel='ZN'>

# %%
Q1 = data['ZN'].quantile(0.25)
Q3 = data['ZN'].quantile(0.75)
Q1, Q3
# Out:
# (0.0, 12.5)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 12.5

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
lower_limit, upper_limit
# Out:
# (-18.75, 31.25)

# %%
data_1[(data_1['ZN'] > upper_limit) | (data_1['ZN'] < lower_limit)]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD    TAX  \
# 39   0.02763  75.0   2.95   0.0  0.428  6.595  21.8   5.4011  3.0  252.0
# 40   0.03359  75.0   2.95   0.0  0.428  7.024  15.8   5.4011  3.0  252.0
# 54   0.01360  75.0   4.00   0.0  0.410  5.888  47.6   7.3197  3.0  469.0
# 55   0.01311  90.0   1.22   0.0  0.403  7.249  21.9   8.6966  5.0  226.0
# 56   0.02055  85.0   0.74   0.0  0.410  6.383  35.7   9.1876  2.0  313.0
# ..       ...   ...    ...   ...    ...    ...   ...      ...  ...    ...
# 351  0.07950  60.0   1.69   0.0  0.411  6.579  35.9  10.7103  4.0  411.0
# 352  0.07244  60.0   1.69   0.0  0.411  5.884  18.5  10.7103  4.0  411.0
# 353  0.01709  90.0   2.02   0.0  0.410  6.728  36.1  12.1265  5.0  187.0
# 354  0.04301  80.0   1.91   0.0  0.413  5.663  21.9  10.5857  4.0  334.0
# 355  0.10659  80.0   1.91   0.0  0.413  5.936  19.5  10.5857  4.0  334.0
#
#      PTRATIO       B  LSTAT  target
# 39      18.3  395.63   4.32    30.8
# ...

# %%
data_2 = data_1[(data_1['ZN'] <= upper_limit) & (data_1['ZN'] >= lower_limit)]
data_2
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_2, x = 'INDUS')
# Out:
# <AxesSubplot:xlabel='INDUS'>

# %%
sns.boxplot(data = data_2, x = 'CHAS')
# Out:
# <AxesSubplot:xlabel='CHAS'>

# %%
Q1 = data_2['CHAS'].quantile(0.25)
Q3 = data_2['CHAS'].quantile(0.75)
Q1, Q3
# Out:
# (0.0, 0.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (0.0, 0.0)

# %%
data_2[(data_2['CHAS'] > upper_limit) | (data_2['CHAS'] < lower_limit)]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 142  3.32105   0.0  19.58   1.0  0.8710  5.403  100.0  1.3216   5.0  403.0
# 152  1.12658   0.0  19.58   1.0  0.8710  5.012   88.0  1.6102   5.0  403.0
# 154  1.41385   0.0  19.58   1.0  0.8710  6.129   96.0  1.7494   5.0  403.0
# 155  3.53501   0.0  19.58   1.0  0.8710  6.152   82.6  1.7455   5.0  403.0
# 160  1.27346   0.0  19.58   1.0  0.6050  6.250   92.6  1.7984   5.0  403.0
# 162  1.83377   0.0  19.58   1.0  0.6050  7.802   98.2  2.0407   5.0  403.0
# 163  1.51902   0.0  19.58   1.0  0.6050  8.375   93.9  2.1620   5.0  403.0
# 208  0.13587   0.0  10.59   1.0  0.4890  6.064   59.1  4.2392   4.0  277.0
# 209  0.43571   0.0  10.59   1.0  0.4890  5.344  100.0  3.8750   4.0  277.0
# 210  0.17446   0.0  10.59   1.0  0.4890  5.960   92.1  3.8771   4.0  277.0
# 211  0.37578   0.0  10.59   1.0  0.4890  5.404   88.6  3.6650   4.0  277.0
# ...

# %%
data_3 = data_2[(data_2['CHAS'] <= upper_limit) & (data_2['CHAS'] >= lower_limit)]
data_3
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_3, x = 'NOX')
# Out:
# <AxesSubplot:xlabel='NOX'>

# %%
Q1 = data_3['NOX'].quantile(0.25)
Q3 = data_3['NOX'].quantile(0.75)
Q1, Q3
# Out:
# (0.469, 0.605)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.136

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (0.26499999999999996, 0.8089999999999999)

# %%
data_3[(data_3['NOX'] > upper_limit) | (data_3['NOX'] < lower_limit)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 143  4.09740  0.0  19.58   0.0  0.871  5.468  100.0  1.4118  5.0  403.0
# 144  2.77974  0.0  19.58   0.0  0.871  4.903   97.8  1.3459  5.0  403.0
# 145  2.37934  0.0  19.58   0.0  0.871  6.130  100.0  1.4191  5.0  403.0
# 146  2.15505  0.0  19.58   0.0  0.871  5.628  100.0  1.5166  5.0  403.0
# 147  2.36862  0.0  19.58   0.0  0.871  4.926   95.7  1.4608  5.0  403.0
# 148  2.33099  0.0  19.58   0.0  0.871  5.186   93.8  1.5296  5.0  403.0
# 149  2.73397  0.0  19.58   0.0  0.871  5.597   94.9  1.5257  5.0  403.0
# 150  1.65660  0.0  19.58   0.0  0.871  6.122   97.3  1.6180  5.0  403.0
# 151  1.49632  0.0  19.58   0.0  0.871  5.404  100.0  1.5916  5.0  403.0
# 153  2.14918  0.0  19.58   0.0  0.871  5.709   98.5  1.6232  5.0  403.0
# 156  2.44668  0.0  19.58   0.0  0.871  5.272   94.0  1.7364  5.0  403.0
# 159  1.42502  0.0  19.58   0.0  0.871  6.510  100.0  1.7659  5.0  403.0
#
# ...

# %%
data_4 = data_3[(data_3['NOX'] <= upper_limit) & (data_3['NOX'] >= lower_limit)]
data_4
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_4, x = 'RM')
# Out:
# <AxesSubplot:xlabel='RM'>

# %%
Q1 = data_4['RM'].quantile(0.25)
Q3 = data_4['RM'].quantile(0.75)
Q1, Q3
# Out:
# (5.913, 6.484)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.5709999999999997

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (5.056500000000001, 7.3405)

# %%
data_4[(data_4['RM'] > upper_limit) | (data_4['RM'] < lower_limit)]
# Out:
#         CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 97   0.12083   0.0   2.89   0.0  0.4450  8.069   76.0  3.4952   2.0  276.0
# 98   0.08187   0.0   2.89   0.0  0.4450  7.820   36.9  3.4952   2.0  276.0
# 99   0.06860   0.0   2.89   0.0  0.4450  7.416   62.5  3.4952   2.0  276.0
# 141  1.62864   0.0  21.89   0.0  0.6240  5.019  100.0  1.4394   4.0  437.0
# 161  1.46336   0.0  19.58   0.0  0.6050  7.489   90.8  1.9709   5.0  403.0
# 166  2.01019   0.0  19.58   0.0  0.6050  7.929   96.2  2.0459   5.0  403.0
# 180  0.06588   0.0   2.46   0.0  0.4880  7.765   83.3  2.7410   3.0  193.0
# 186  0.05602   0.0   2.46   0.0  0.4880  7.831   53.6  3.1992   3.0  193.0
# 224  0.31533   0.0   6.20   0.0  0.5040  8.266   78.3  2.8944   8.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.5040  8.725   83.0  2.8944   8.0  307.0
# 226  0.38214   0.0   6.20   0.0  0.5040  8.040   86.5  3.2157   8.0  307.0
# ...

# %%
data_5 = data_4[(data_4['RM'] <= upper_limit) & (data_4['RM'] >= lower_limit)]
data_5
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_5, x = 'AGE')
# Out:
# <AxesSubplot:xlabel='AGE'>

# %%
sns.boxplot(data = data_5, x = 'DIS')
# Out:
# <AxesSubplot:xlabel='DIS'>

# %%
Q1 = data_5['DIS'].quantile(0.25)
Q3 = data_5['DIS'].quantile(0.75)
Q1, Q3
# Out:
# (2.4091, 5.1004)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 2.6912999999999996

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-1.6278499999999991, 9.137349999999998)

# %%
data_5[(data_5['DIS'] > upper_limit) | (data_5['DIS'] < lower_limit)]
# Out:
#        CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# 64  0.01951  17.5   1.38   0.0  0.4161  7.104  59.5  9.2229  3.0  216.0
#
#     PTRATIO       B  LSTAT  target
# 64     18.6  393.24   8.05    33.0

# %%
data_6 = data_5[(data_5['DIS'] <= upper_limit) & (data_5['DIS'] >= lower_limit)]
data_6
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_6, x = 'RAD')
# Out:
# <AxesSubplot:xlabel='RAD'>

# %%
Q1 = data_6['RAD'].quantile(0.25)
Q3 = data_6['RAD'].quantile(0.75)
Q1, Q3
# Out:
# (4.0, 6.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 2.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5* IQR
lower_limit, upper_limit
# Out:
# (1.0, 9.0)

# %%
data_6[(data_6['RAD'] > upper_limit) | (data_6['RAD'] < lower_limit)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 359  4.26131  0.0   18.1   0.0  0.770  6.112   81.3  2.5091  24.0  666.0
# 360  4.54192  0.0   18.1   0.0  0.770  6.398   88.0  2.5182  24.0  666.0
# 361  3.83684  0.0   18.1   0.0  0.770  6.251   91.1  2.2955  24.0  666.0
# 362  3.67822  0.0   18.1   0.0  0.770  5.362   96.2  2.1036  24.0  666.0
# 383  7.99248  0.0   18.1   0.0  0.700  5.520  100.0  1.5331  24.0  666.0
# 389  8.15174  0.0   18.1   0.0  0.700  5.390   98.9  1.7281  24.0  666.0
# 390  6.96215  0.0   18.1   0.0  0.700  5.713   97.0  1.9265  24.0  666.0
# 391  5.29305  0.0   18.1   0.0  0.700  6.051   82.5  2.1678  24.0  666.0
# 393  8.64476  0.0   18.1   0.0  0.693  6.193   92.6  1.7912  24.0  666.0
# 395  8.71675  0.0   18.1   0.0  0.693  6.471   98.8  1.7257  24.0  666.0
# 396  5.87205  0.0   18.1   0.0  0.693  6.405   96.0  1.6768  24.0  666.0
# 397  7.67202  0.0   18.1   0.0  0.693  5.747   98.9  1.6334  24.0  666.0
# ...

# %%
data_7 = data_6[(data_6['RAD'] <= upper_limit) & (data_6['RAD'] >= lower_limit)]
data_7
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_7, x = 'TAX')
# Out:
# <AxesSubplot:xlabel='TAX'>

# %%
Q1 = data_7['TAX'].quantile(0.25)
Q3 = data_7['TAX'].quantile(0.75)
Q1, Q3
# Out:
# (270.75, 384.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 113.25

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (100.875, 553.875)

# %%
data_7[(data_7['TAX'] > upper_limit) | (data_7['TAX'] < lower_limit)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 488  0.15086  0.0  27.74   0.0  0.609  5.454  92.7  1.8209  4.0  711.0
# 489  0.18337  0.0  27.74   0.0  0.609  5.414  98.3  1.7554  4.0  711.0
# 490  0.20746  0.0  27.74   0.0  0.609  5.093  98.0  1.8226  4.0  711.0
# 491  0.10574  0.0  27.74   0.0  0.609  5.983  98.8  1.8681  4.0  711.0
# 492  0.11132  0.0  27.74   0.0  0.609  5.983  83.5  2.1099  4.0  711.0
#
#      PTRATIO       B  LSTAT  target
# 488     20.1  395.09  18.06    15.2
# 489     20.1  344.05  23.97     7.0
# 490     20.1  318.43  29.68     8.1
# 491     20.1  390.11  18.07    13.6
# 492     20.1  396.90  13.35    20.1

# %%
data_8 = data_7[(data_7['TAX'] <= upper_limit) & (data_7['TAX'] >= lower_limit)]
data_8
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_8, x = 'PTRATIO')
# Out:
# <AxesSubplot:xlabel='PTRATIO'>

# %%
sns.boxplot(data = data_8, x = 'B')
# Out:
# <AxesSubplot:xlabel='B'>

# %%
Q1 = data_8['B'].quantile(0.25)
Q3 = data_8['B'].quantile(0.75)
Q1, Q3
# Out:
# (385.64, 396.9)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 11.259999999999991

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (368.75, 413.78999999999996)

# %%
data_8[(data_8['B'] > upper_limit) | (data_8['B'] < lower_limit)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 18   0.80271  0.0   8.14   0.0  0.538  5.456   36.6  3.7965  4.0  307.0
# 25   0.84054  0.0   8.14   0.0  0.538  5.599   85.7  4.4546  4.0  307.0
# 27   0.95577  0.0   8.14   0.0  0.538  6.047   88.8  4.4534  4.0  307.0
# 30   1.13081  0.0   8.14   0.0  0.538  5.713   94.1  4.2330  4.0  307.0
# 32   1.38799  0.0   8.14   0.0  0.538  5.950   82.0  3.9900  4.0  307.0
# 33   1.15172  0.0   8.14   0.0  0.538  5.701   95.0  3.7872  4.0  307.0
# 34   1.61282  0.0   8.14   0.0  0.538  6.096   96.9  3.7598  4.0  307.0
# 95   0.12204  0.0   2.89   0.0  0.445  6.625   57.8  3.4952  2.0  276.0
# 102  0.22876  0.0   8.56   0.0  0.520  6.405   85.4  2.7147  5.0  384.0
# 115  0.17134  0.0  10.01   0.0  0.547  5.928   88.2  2.4631  6.0  432.0
# 118  0.13058  0.0  10.01   0.0  0.547  5.872   73.1  2.4775  6.0  432.0
# 126  0.38735  0.0  25.65   0.0  0.581  5.613   95.6  1.7572  2.0  188.0
# ...

# %%
data_9 = data_8[(data_8['B'] <= upper_limit) & (data_8['B'] >= lower_limit)]
data_9
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
sns.boxplot(data = data_9, x = 'LSTAT')
# Out:
# <AxesSubplot:xlabel='LSTAT'>

# %%
Q1 = data_9['LSTAT'].quantile(0.25)
Q3 = data_9['LSTAT'].quantile(0.75)
Q1, Q3
# Out:
# (7.44, 13.45)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 6.009999999999999

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-1.5749999999999984, 22.464999999999996)

# %%
data_9[(data_9['LSTAT'] > upper_limit) | (data_9['LSTAT'] < lower_limit)]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 8    0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 48   0.25387   0.0   6.91   0.0  0.448  5.399   95.3  5.8700  3.0  233.0
# 123  0.15038   0.0  25.65   0.0  0.581  5.856   97.0  1.9444  2.0  188.0
# 140  0.29090   0.0  21.89   0.0  0.624  6.174   93.6  1.6119  4.0  437.0
#
#      PTRATIO       B  LSTAT  target
# 8       15.2  386.63  29.93    16.5
# 48      17.9  396.90  30.81    14.4
# 123     19.1  370.31  25.41    17.3
# 140     21.2  388.08  24.16    14.0

# %%
data_10 = data_9[(data_9['LSTAT'] <= upper_limit) & (data_9['LSTAT'] >= lower_limit)]
data_10
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
data_without_outliers = data_10.copy()

data_without_outliers.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = data_without_outliers.iloc[:, : -1]
y = data_without_outliers.iloc[:, -1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled[:10]
# Out:
# array([[-0.81920062,  1.28396533, -1.20565219,  0.        ,  0.50995189,
#          0.88250449,  0.12528742, -0.108571  , -2.30337056, -0.14479672,
#         -1.70142799,  0.80929696, -1.37208753],
#        [-0.74752023, -0.56147912, -0.29613155,  0.        , -0.60464359,
#          0.49611503,  0.64313618,  0.40210357, -1.64216041, -0.95880054,
#         -0.39367625,  0.80929696, -0.36074167],
#        [-0.74758853, -0.56147912, -0.29613155,  0.        , -0.60464359,
#          2.41300822, -0.02968921,  0.40210357, -1.64216041, -0.95880054,
#         -0.39367625,  0.19095651, -1.60304392],
#        [-0.73024044, -0.56147912, -1.23049204,  0.        , -0.78233273,
#          1.94382101, -0.60801666,  1.03970443, -0.98095027, -1.26028344,
#          0.07711437,  0.46442403, -1.86803599],
#        [-0.60497905, -0.56147912, -1.23049204,  0.        , -0.78233273,
#          2.31766536, -0.29050355,  1.03970443, -0.98095027, -1.26028344,
#          0.07711437,  0.80929696, -1.28699834],
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### Modeling and Evaluation

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test, y_test)
# Out:
# 0.6929518356511195

# %%
reg.score(X_train, y_train)
# Out:
# 0.762174404848984

# %% [markdown]
# ### Regression Metrics

# %% [markdown]
# - R^2 Score
# - Mean absolute error
# - Mean square error
# - Root mean square error
# - Mean absolute percentage error

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([21.75360794, 22.46741913, 25.34579551, 24.10208058, 24.74897095,
#        16.56788754, 20.01718398, 20.12677858, 24.39138908, 14.86415761,
#        22.3571728 , 21.29858842, 22.84776432, 24.9167537 , 24.04496392,
#        26.24982295, 24.22722023, 14.45629556, 18.22200326, 25.40515536,
#        20.3697556 , 23.20407903, 25.62873652, 23.93689172, 25.45794494,
#        17.53093109, 23.63675252, 22.71459084, 18.56839909, 18.16807686,
#        24.18127575, 26.16507525, 31.73033777, 20.33629083, 24.14813379,
#        19.329467  , 23.8662182 , 33.98829832, 20.92849803, 20.08067639,
#        18.54377597, 19.41195157, 20.90392726])

# %%
X.columns.values
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype=object)

# %%
reg.predict(scaler.transform([[0.00632,18.0,2.31,0.0, 0.538, 6.575, 65.2, 4.0900, 1.0, 296.0,15.3, 396.90, 4.98]]))
# Out:
# array([24.5800723])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6929518356511195

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 1.7124722961511027

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 4.570421059728997

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 2.1378543120916818

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
mape
# Out:
# 0.08377590883751916

# %% [markdown]
# ### Hyperparameter tuning

# %% [markdown]
# Feature engineering > Hyperparamter tuning

# %% [markdown]
# - Feature engineering and test our model
# - Principal Component Analysis (PCA)
# - Hyperparameter tuning.

# %%
data_without_outliers.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df = data_without_outliers.copy()

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ### Feature engineering/selection
# - Create features from existing features
# - On the other hand, we can say that feature selection is the ability to select features from existing features in other not to overwhelm the machine leaning model.

# %% [markdown]
# Feature selection using Pearson's rank correlation

# %%
corr = df.corr()
corr
# Out:
#              CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.117168  0.196629   NaN  0.475402 -0.083628  0.370491
# ZN      -0.117168  1.000000 -0.280390   NaN -0.322786  0.211165 -0.219639
# INDUS    0.196629 -0.280390  1.000000   NaN  0.459774 -0.235978  0.310183
# CHAS          NaN       NaN       NaN   NaN       NaN       NaN       NaN
# NOX      0.475402 -0.322786  0.459774   NaN  1.000000 -0.028433  0.659896
# RM      -0.083628  0.211165 -0.235978   NaN -0.028433  1.000000 -0.021014
# AGE      0.370491 -0.219639  0.310183   NaN  0.659896 -0.021014  1.000000
# DIS     -0.254671  0.495640 -0.423247   NaN -0.757590 -0.010369 -0.576895
# RAD      0.078458  0.359931 -0.193896   NaN -0.100119 -0.068062 -0.113584
# TAX      0.206791 -0.165333  0.367073   NaN  0.304147 -0.188748  0.228668
# PTRATIO  0.090879 -0.357699  0.349088   NaN  0.080306 -0.306288  0.120157
# B       -0.123093 -0.115195 -0.056030   NaN  0.093154 -0.018630  0.026315
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,
           annot=True,
           fmt='.2f',
           cmap='YlGnBu')
plt.show()

# %% [markdown]
# dropping the `CHAS`, `LSTAT`, `DIS`, `NOX`, `AGE`

# %%
df = df.drop(['CHAS', 'LSTAT', 'DIS', 'NOX', 'AGE'], axis = 1)
df.head()
# Out:
#       CRIM    ZN  INDUS     RM  RAD    TAX  PTRATIO       B  target
# 0  0.00632  18.0   2.31  6.575  1.0  296.0     15.3  396.90    24.0
# 1  0.02731   0.0   7.07  6.421  2.0  242.0     17.8  396.90    21.6
# 2  0.02729   0.0   7.07  7.185  2.0  242.0     17.8  392.83    34.7
# 3  0.03237   0.0   2.18  6.998  3.0  222.0     18.7  394.63    33.4
# 4  0.06905   0.0   2.18  7.147  3.0  222.0     18.7  396.90    36.2

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled[:10]
# Out:
# array([[-0.81920062,  1.28396533, -1.20565219,  0.88250449, -2.30337056,
#         -0.14479672, -1.70142799,  0.80929696],
#        [-0.74752023, -0.56147912, -0.29613155,  0.49611503, -1.64216041,
#         -0.95880054, -0.39367625,  0.80929696],
#        [-0.74758853, -0.56147912, -0.29613155,  2.41300822, -1.64216041,
#         -0.95880054, -0.39367625,  0.19095651],
#        [-0.73024044, -0.56147912, -1.23049204,  1.94382101, -0.98095027,
#         -1.26028344,  0.07711437,  0.46442403],
#        [-0.60497905, -0.56147912, -1.23049204,  2.31766536, -0.98095027,
#         -1.26028344,  0.07711437,  0.80929696],
#        [-0.73884619, -0.56147912, -1.23049204,  0.51869623, -0.98095027,
#         -1.26028344,  0.07711437,  0.38694157],
#        [-0.53927488,  0.72007952, -0.14327094, -0.53007518,  0.34147003,
#          0.08131546, -1.75373806,  0.61179264],
#        [-0.34714822,  0.72007952, -0.14327094, -0.12863158,  0.34147003,
#          0.08131546, -1.75373806,  0.80929696],
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=2)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.7326251490020189

# %%
lin_reg.score(X_train, y_train)
# Out:
# 0.6689470358229892

# %% [markdown]
# ### Hyperparameter tuning
#
# - GridSearchCV
# - RandomizedSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg = RandomForestRegressor()
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
reg.score(X_test, y_test)
# Out:
# 0.8229955485262622

# %%
reg.score(X_train, y_train)
# Out:
# 0.9455439217024095

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
grid = {
    'n_estimators' : [100, 200],
    'max_features' : [1.0, 2.0, 3.0],
    'min_samples_split' : [2, 4, 6, 8],
    'min_samples_leaf' : [1, 3, 5, 7]
}

reg_grid = GridSearchCV(reg,
                       param_grid = grid,
                       verbose = True,
                       n_jobs = -1,
                       return_train_score = True,
                       cv = 5)

reg_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_features': [1.0, 2.0, 3.0],
#                          'min_samples_leaf': [1, 3, 5, 7],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [100, 200]},
#              return_train_score=True, verbose=True)

# %%
reg_grid.score(X_test, y_test)
# Out:
# 0.7957593093728923

# %% [markdown]
# ### RandomizedSearchCV

# %%
rs = {
    'n_estimators' : [100, 200],
    'max_features' : [1.0, 2.0, 3.0],
    'min_samples_split' : [2, 4, 6, 8],
    'min_samples_leaf' : [1, 3, 5, 7]
}

reg_rs = RandomizedSearchCV(reg,
                           param_distributions = rs,
                           cv = 5,
                           verbose = True,
                           n_jobs = -1,
                           return_train_score = True)

reg_rs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_features': [1.0, 2.0, 3.0],
#                                         'min_samples_leaf': [1, 3, 5, 7],
#                                         'min_samples_split': [2, 4, 6, 8],
#                                         'n_estimators': [100, 200]},
#                    return_train_score=True, verbose=True)

# %%
reg_rs.score(X_test, y_test)
# Out:
# 0.7789453781403292

# %%
reg_rs.score(X_train, y_train)
# Out:
# 0.7888048139400181

# %% [markdown]
# Project
#
# - Stock market analysis.
# The link to datasets https://www.kaggle.com/datasets/paultimothymooney/stock-market-data
