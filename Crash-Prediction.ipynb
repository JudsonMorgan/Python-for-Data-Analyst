# %% [markdown]
# ### Import Data Visualization Library!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()
# %matplotlib inline

# %% [markdown]
# #### Load the data

# %%
crash_df = pd.read_csv("data/Crash_Data.csv")

#view the data
crash_df.head()
# Out:
#    Crash ID State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# 0  20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 1  20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 2  20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 3  20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 4  20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age  \
# 0                           NaN                           NaN  ...  38
# 1                            No                            No  ...  28
# 2                           NaN                           NaN  ...  19
# 3                           NaN                           NaN  ...  23
# 4                           NaN                           NaN  ...  46
#
#    National Remoteness Areas           SA4 Name 2016  National LGA Name 2017  \
# ...

# %%
crash_df.shape
# Out:
# (52843, 23)

# %%
crash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52843 entries, 0 to 52842
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       52843 non-null  int64
#  1   State                          52843 non-null  object
#  2   Month                          52843 non-null  int64
#  3   Year                           52843 non-null  int64
#  4   Dayweek                        52843 non-null  object
#  5   Time                           52803 non-null  object
#  6   Crash Type                     52843 non-null  object
#  7   Bus Involvement                52821 non-null  object
#  8   Heavy Rigid Truck Involvement  32328 non-null  object
#  9   Articulated Truck Involvement  52821 non-null  object
#  10  Speed Limit                    52141 non-null  object
#  11  Road User                      52843 non-null  object
# ...

# %%
crash_df.set_index('Crash ID', inplace=True)

crash_df.head()
# Out:
#          State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit  ... Age  National Remoteness Areas  \
# Crash ID              ...
# ...

# %%
data = crash_df.copy()

data.head()
# Out:
#          State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit  ... Age  National Remoteness Areas  \
# Crash ID              ...
# ...

# %%
data['State'].unique()
# Out:
# array(['Vic', 'SA', 'Qld', 'WA', 'NSW', 'NT', 'ACT', 'Tas'], dtype=object)

# %%
data.describe()
# Out:
#               Month          Year           Age
# count  52843.000000  52843.000000  52843.000000
# mean       6.568685   2002.729974     39.662377
# std        3.457347      9.378570     21.806198
# min        1.000000   1989.000000     -9.000000
# 25%        4.000000   1995.000000     22.000000
# 50%        7.000000   2002.000000     34.000000
# 75%       10.000000   2010.000000     55.000000
# max       12.000000   2021.000000    101.000000

# %%
data.isna().sum()
# Out:
# State                                0
# Month                                0
# Year                                 0
# Dayweek                              0
# Time                                40
# Crash Type                           0
# Bus Involvement                     22
# Heavy Rigid Truck Involvement    20515
# Articulated Truck Involvement       22
# Speed Limit                        702
# Road User                            0
# Gender                              27
# Age                                  0
# National Remoteness Areas        45965
# SA4 Name 2016                    45951
# National LGA Name 2017           45950
# National Road Type               45966
# Christmas Period                     0
# Easter Period                        0
# Age Group                           90
# Day of week                          0
# Time of day                          0
# dtype: int64

# %% [markdown]
# drop columns with missing values greater than 60%

# %%
data.shape[0]
# Out:
# 52843

# %%
data = data.drop(['National Remoteness Areas', 'SA4 Name 2016','National LGA Name 2017','National Road Type'], axis=1)

data.head()
# Out:
#          State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# ...

# %%
data['Road User'].value_counts()
# Out:
# Driver                          23816
# Passenger                       12269
# Pedestrian                       8242
# Motorcycle rider                 6637
# Pedal cyclist                    1424
# Motorcycle pillion passenger      363
# Other/-9                           92
# Name: Road User, dtype: int64

# %%
data.groupby('Age')['Crash Type'].value_counts()
# Out:
# Age   Crash Type
# -9    Multiple       46
#       Single         44
#  0    Multiple      136
#       Single         90
#  1    Single        119
#                    ...
#  98   Single          2
#  99   Multiple        3
#       Single          3
#  100  Single          1
#  101  Multiple        2
# Name: Crash Type, Length: 204, dtype: int64

# %%
data['Crash Type'].value_counts()
# Out:
# Single      29249
# Multiple    23594
# Name: Crash Type, dtype: int64

# %%
#reordering of the columns
data.columns.values
# Out:
# array(['State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type',
#        'Bus Involvement', 'Heavy Rigid Truck Involvement',
#        'Articulated Truck Involvement', 'Speed Limit', 'Road User',
#        'Gender', 'Age', 'Christmas Period', 'Easter Period', 'Age Group',
#        'Day of week', 'Time of day'], dtype=object)

# %%
columns = ['State', 'Month', 'Year', 'Dayweek', 'Time',
       'Bus Involvement', 'Heavy Rigid Truck Involvement',
       'Articulated Truck Involvement', 'Speed Limit', 'Road User',
       'Gender', 'Age', 'Christmas Period', 'Easter Period', 'Age Group',
       'Day of week', 'Time of day', 'Crash Type']

data = data[columns]
data.head()
# Out:
#          State  Month  Year   Dayweek   Time Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30             NaN
# 20214022    SA      9  2021  Saturday  23:31              No
# 20212096   Vic      9  2021  Saturday  23:00             NaN
# 20212145   Vic      9  2021  Saturday  22:25             NaN
# 20212075   Vic      9  2021  Saturday   5:15             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# 20212133         NaN  Motorcycle rider    Male   38               No
# ...

# %% [markdown]
# ### Target Encodding

# %%
data['Crash Type'] = data['Crash Type'].apply(lambda x: 0 if x == "Single" else 1)

data['Crash Type'].value_counts()
# Out:
# 0    29249
# 1    23594
# Name: Crash Type, dtype: int64

# %%
data.head()
# Out:
#          State  Month  Year   Dayweek   Time Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30             NaN
# 20214022    SA      9  2021  Saturday  23:31              No
# 20212096   Vic      9  2021  Saturday  23:00             NaN
# 20212145   Vic      9  2021  Saturday  22:25             NaN
# 20212075   Vic      9  2021  Saturday   5:15             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# 20212133         NaN  Motorcycle rider    Male   38               No
# ...

# %%
sns.scatterplot(data = data, x = 'Age', y='Crash Type')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Crash Type'>

# %%
data.groupby('Gender')['Crash Type'].value_counts()
# Out:
# Gender       Crash Type
# Female       1              7524
#              0              7478
# Male         0             21764
#              1             16049
# Unspecified  1                 1
# Name: Crash Type, dtype: int64

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan, 'Unspecified'], dtype=object)

# %%
data['Month'].value_counts()
# Out:
# 12    4721
# 3     4673
# 8     4512
# 10    4509
# 5     4447
# 11    4388
# 9     4337
# 6     4333
# 1     4329
# 7     4321
# 4     4298
# 2     3975
# Name: Month, dtype: int64

# %%
data.groupby('Christmas Period')['Crash Type'].value_counts()
# Out:
# Christmas Period  Crash Type
# No                0             28296
#                   1             22912
# Yes               0               953
#                   1               682
# Name: Crash Type, dtype: int64

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan, 'Unspecified'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Male           37813
# Female         15002
# Unspecified        1
# Name: Gender, dtype: int64

# %%
data['Gender'] = data['Gender'].replace('Unspecified', np.nan)

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data.head()
# Out:
#          State  Month  Year   Dayweek   Time Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30             NaN
# 20214022    SA      9  2021  Saturday  23:31              No
# 20212096   Vic      9  2021  Saturday  23:00             NaN
# 20212145   Vic      9  2021  Saturday  22:25             NaN
# 20212075   Vic      9  2021  Saturday   5:15             NaN
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                           NaN                           NaN
# 20214022                            No                            No
# 20212096                           NaN                           NaN
# 20212145                           NaN                           NaN
# 20212075                           NaN                           NaN
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# 20212133         NaN  Motorcycle rider    Male   38               No
# ...

# %% [markdown]
# ### Data cleansing and Preprocessing
#
# - Missing values
# - Data Inconsistency
# - Outlier detection and removal.
# - Feature encoding.

# %% [markdown]
# ### Missing values

# %%
data.isna().sum()
# Out:
# State                                0
# Month                                0
# Year                                 0
# Dayweek                              0
# Time                                40
# Bus Involvement                     22
# Heavy Rigid Truck Involvement    20515
# Articulated Truck Involvement       22
# Speed Limit                        702
# Road User                            0
# Gender                              28
# Age                                  0
# Christmas Period                     0
# Easter Period                        0
# Age Group                           90
# Day of week                          0
# Time of day                          0
# Crash Type                           0
# dtype: int64

# %%
for label, content in data.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isna(content).sum():
            print(label)
#         print(label)

# %%
for label, content in data.items():
    if pd.api.types.is_string_dtype(content):
        if pd.isna(content).sum():
            print(label)
#         print(label)
# Out:
# Time
# Bus Involvement
# Heavy Rigid Truck Involvement
# Articulated Truck Involvement
# Speed Limit
# Gender
# Age Group

# %%
for label, content in data.items():
    if pd.api.types.is_string_dtype(content):
        if pd.isna(content).sum():
            data[label] = data[label].fillna(method = 'bfill')

# %%
data.isna().sum()
# Out:
# State                             0
# Month                             0
# Year                              0
# Dayweek                           0
# Time                              0
# Bus Involvement                   0
# Heavy Rigid Truck Involvement    10
# Articulated Truck Involvement     0
# Speed Limit                       0
# Road User                         0
# Gender                            0
# Age                               0
# Christmas Period                  0
# Easter Period                     0
# Age Group                         0
# Day of week                       0
# Time of day                       0
# Crash Type                        0
# dtype: int64

# %%
data['Heavy Rigid Truck Involvement'].dtype
# Out:
# dtype('O')

# %%
data['Heavy Rigid Truck Involvement'] = data['Heavy Rigid Truck Involvement'].fillna(method = 'ffill')

# %%
data.isna().sum()
# Out:
# State                            0
# Month                            0
# Year                             0
# Dayweek                          0
# Time                             0
# Bus Involvement                  0
# Heavy Rigid Truck Involvement    0
# Articulated Truck Involvement    0
# Speed Limit                      0
# Road User                        0
# Gender                           0
# Age                              0
# Christmas Period                 0
# Easter Period                    0
# Age Group                        0
# Day of week                      0
# Time of day                      0
# Crash Type                       0
# dtype: int64

# %% [markdown]
# ### Inconsistent Data

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Speed Limit'].unique()
# Out:
# array(['110', '100', '60', '80', '50', '70', '90', '40', '130', '20',
#        '10', '30', '25', '15', '<40', '5', 'Unspecified', '75', 110, 100,
#        60, -9, 80, 90, 70, 40, 50, 30, 20, 75], dtype=object)

# %%
data['Speed Limit'] = data['Speed Limit'].replace('<40', '15')
data['Speed Limit'] = data['Speed Limit'].replace('Unspecified', '75')
data['Speed Limit'] = data['Speed Limit'].replace('-9', '80')

# %%
data['Speed Limit'].unique()
# Out:
# array(['110', '100', '60', '80', '50', '70', '90', '40', '130', '20',
#        '10', '30', '25', '15', '5', '75', 110, 100, 60, -9, 80, 90, 70,
#        40, 50, 30, 20, 75], dtype=object)

# %%
data['Speed Limit'] = data['Speed Limit'].replace(-9, 9)

# %%
data['Speed Limit'].unique()
# Out:
# array(['110', '100', '60', '80', '50', '70', '90', '40', '130', '20',
#        '10', '30', '25', '15', '5', '75', 110, 100, 60, 9, 80, 90, 70, 40,
#        50, 30, 20, 75], dtype=object)

# %%
data['Road User'].unique()
# Out:
# array(['Motorcycle rider', 'Pedestrian', 'Passenger', 'Driver',
#        'Other/-9', 'Pedal cyclist', 'Motorcycle pillion passenger'],
#       dtype=object)

# %%
data['Road User'] = data['Road User'].replace('Other/-9', 'Other')

data['Road User'].unique()
# Out:
# array(['Motorcycle rider', 'Pedestrian', 'Passenger', 'Driver', 'Other',
#        'Pedal cyclist', 'Motorcycle pillion passenger'], dtype=object)

# %%
data['Crash Type'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ### Outlier Detection and Removal

# %%
data.head()
# Out:
#          State  Month  Year   Dayweek   Time Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021    Sunday   0:30              No
# 20214022    SA      9  2021  Saturday  23:31              No
# 20212096   Vic      9  2021  Saturday  23:00              No
# 20212145   Vic      9  2021  Saturday  22:25              No
# 20212075   Vic      9  2021  Saturday   5:15              No
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                            No                            No
# 20214022                            No                            No
# 20212096                            No                            No
# 20212145                            No                            No
# 20212075                            No                            No
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# 20212133         110  Motorcycle rider    Male   38               No
# ...

# %%
data.describe()
# Out:
#               Month          Year           Age    Crash Type
# count  52843.000000  52843.000000  52843.000000  52843.000000
# mean       6.568685   2002.729974     39.662377      0.446492
# std        3.457347      9.378570     21.806198      0.497133
# min        1.000000   1989.000000     -9.000000      0.000000
# 25%        4.000000   1995.000000     22.000000      0.000000
# 50%        7.000000   2002.000000     34.000000      0.000000
# 75%       10.000000   2010.000000     55.000000      1.000000
# max       12.000000   2021.000000    101.000000      1.000000

# %%
sns.boxplot(data = data,
           x = 'Month')
plt.show()

# %%
sns.boxplot(data = data,
           x = 'Year')
plt.show()

# %%
sns.boxplot(data = data,
           x = 'Age')
plt.show()

# %% [markdown]
# ### Feature Selection

# %%
corr = data.corr()
corr
# Out:
#                Month      Year       Age  Crash Type
# Month       1.000000 -0.022422 -0.008221   -0.007086
# Year       -0.022422  1.000000  0.126277   -0.016037
# Age        -0.008221  0.126277  1.000000    0.079767
# Crash Type -0.007086 -0.016037  0.079767    1.000000

# %%
data = data.drop(['Age Group', 'Dayweek'], axis=1)
data.head()
# Out:
#          State  Month  Year   Time Bus Involvement  \
# Crash ID
# 20212133   Vic      9  2021   0:30              No
# 20214022    SA      9  2021  23:31              No
# 20212096   Vic      9  2021  23:00              No
# 20212145   Vic      9  2021  22:25              No
# 20212075   Vic      9  2021   5:15              No
#
#          Heavy Rigid Truck Involvement Articulated Truck Involvement  \
# Crash ID
# 20212133                            No                            No
# 20214022                            No                            No
# 20212096                            No                            No
# 20212145                            No                            No
# 20212075                            No                            No
#
#          Speed Limit         Road User  Gender  Age Christmas Period  \
# Crash ID
# 20212133         110  Motorcycle rider    Male   38               No
# ...

# %%
data = data.drop('Time', axis=1)

# %%
for label, content in data.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# State
# Bus Involvement
# Heavy Rigid Truck Involvement
# Articulated Truck Involvement
# Speed Limit
# Road User
# Gender
# Christmas Period
# Easter Period
# Day of week
# Time of day

# %%
data['Speed Limit'].unique()
# Out:
# array(['110', '100', '60', '80', '50', '70', '90', '40', '130', '20',
#        '10', '30', '25', '15', '5', '75', 110, 100, 60, 9, 80, 90, 70, 40,
#        50, 30, 20, 75], dtype=object)

# %%
data['Speed Limit'] = data['Speed Limit'].astype('int')

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

le = LabelEncoder()
data['State'] = le.fit_transform(data['State'])
data['Bus Involvement'] = le.fit_transform(data['Bus Involvement'])
data['Heavy Rigid Truck Involvement'] = le.fit_transform(data['Heavy Rigid Truck Involvement'])
data['Articulated Truck Involvement'] = le.fit_transform(data['Articulated Truck Involvement'])
data['Road User'] = le.fit_transform(data['Road User'])
data['Gender'] = le.fit_transform(data['Gender'])
data['Christmas Period'] = le.fit_transform(data['Christmas Period'])
data['Easter Period'] = le.fit_transform(data['Easter Period'])
data['Day of week'] = le.fit_transform(data['Day of week'])
data['Time of day'] = le.fit_transform(data['Time of day'])

data.head()
# Out:
#           State  Month  Year  Bus Involvement  Heavy Rigid Truck Involvement  \
# Crash ID
# 20212133      6      9  2021                0                              0
# 20214022      4      9  2021                0                              0
# 20212096      6      9  2021                0                              0
# 20212145      6      9  2021                0                              0
# 20212075      6      9  2021                0                              0
#
#           Articulated Truck Involvement  Speed Limit  Road User  Gender  Age  \
# Crash ID
# 20212133                              0          110          2       1   38
# 20214022                              0          110          6       0   28
# 20212096                              0          100          4       1   19
# 20212145                              0          100          0       1   23
# 20212075                              0          100          2       1   46
#
# ...

# %%
data['Speed Limit'].unique()
# Out:
# array([110, 100,  60,  80,  50,  70,  90,  40, 130,  20,  10,  30,  25,
#         15,   5,  75,   9])

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin

class CustomerScaler(BaseEstimator, TransformerMixin):
    
    def __init__(self, columns, copy=True, with_mean=True, with_std=True):
        self.scaler = StandardScaler(copy=copy, with_mean=with_mean, with_std=with_std)
        self.columns = columns
        self.copy = copy
        self.with_mean = with_mean
        self.with_std = with_std
    
    def fit(self, X, y=None):
        self.scaler = StandardScaler(copy=self.copy, with_mean=self.with_mean, with_std=self.with_std)
        self.scaler.fit(X[self.columns], y)
        self.mean = np.mean(X[self.columns])
        self.var = np.var(X[self.columns])
        return self
    def transform(self, X, y=None, copy=None):
        init_col_order = X.columns
        X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
        X_not_scaled = X.loc[:, ~X.columns.isin(self.columns)]
        return pd.concat([X_not_scaled, X_scaled], axis = 1)[init_col_order]

# %%
X = data.iloc[:, : -1]
y = data.iloc[:, -1]

# %%
X.columns.values
# Out:
# array(['State', 'Month', 'Year', 'Bus Involvement',
#        'Heavy Rigid Truck Involvement', 'Articulated Truck Involvement',
#        'Speed Limit', 'Road User', 'Gender', 'Age', 'Christmas Period',
#        'Easter Period', 'Day of week', 'Time of day'], dtype=object)

# %%
columns_to_omit = ["State", 'Bus Involvement', 'Heavy Rigid Truck Involvement', 'Articulated Truck Involvement', 'Road User', 'Gender', 'Christmas Period', 'Easter Period', 'Day of week', 'Time of day']

#using list comprehension to omit encoded columns
columns_to_scale = [x for x in X.columns.values if x not in columns_to_omit]
columns_to_scale
# Out:
# ['Month', 'Year', 'Speed Limit', 'Age']

# %%
scaler = CustomerScaler(columns_to_scale)
scaler
# Out:
# CustomerScaler(columns=['Month', 'Year', 'Speed Limit', 'Age'])

# %%
scaler.fit(X)
# Out:
# CustomerScaler(columns=['Month', 'Year', 'Speed Limit', 'Age'])

# %%
# X_scaled = scaler.transform(X)
# X_scaled = X_scaled.reset_index()
