# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data/cardio_base.csv')

data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0  18393       2     168    62.0    110     80            1      0
# 1   1  20228       1     156    85.0    140     90            3      0
# 2   2  18857       1     165    64.0    130     70            3      0
# 3   3  17623       2     169    82.0    150    100            1      0
# 4   4  17474       1     156    56.0    100     60            1      0

# %%
data['age'] = data['age']/365

data['age'] = round(data['age'], 0)

data['age'] = data['age'].astype('int')

data.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0   0   50       2     168    62.0    110     80            1      0
# 1   1   55       1     156    85.0    140     90            3      0
# 2   2   52       1     165    64.0    130     70            3      0
# 3   3   48       2     169    82.0    150    100            1      0
# 4   4   48       1     156    56.0    100     60            1      0

# %%
data.set_index('id', inplace=True)
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50       2     168    62.0    110     80            1      0
# 1    55       1     156    85.0    140     90            3      0
# 2    52       1     165    64.0    130     70            3      0
# 3    48       2     169    82.0    150    100            1      0
# 4    48       1     156    56.0    100     60            1      0

# %%
data.shape
# Out:
# (70000, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   smoke        70000 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 4.8 MB

# %%
data['gender'] = data['gender'].apply(lambda x: "Male" if x == 1 else "Female")

data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
# line plot

a = np.array([1, 2, 4, 5])
b = np.array([2, 4, 6, 8])

line = pd.Series(a)
line.plot()
# Out:
# <AxesSubplot:>

# %%
line_2 = pd.Series(b)
line_2.plot()
# Out:
# <AxesSubplot:>

# %%
google = pd.read_csv('data/google.csv', parse_dates=['Date'], index_col='Date')

google.head()
# Out:
#              Close
# Date
# 2014-01-02  556.00
# 2014-01-03  551.95
# 2014-01-04     NaN
# 2014-01-05     NaN
# 2014-01-06  558.10

# %%
google['Close'].plot(title = "Google Stock Price")
plt.show()

# %%
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
data['gender'].value_counts().plot(kind='barh')
plt.xlabel("Counts")
plt.ylabel('Gender')
plt.title('Gender Distribution', fontweight = 'bold', fontsize=16)
plt.show()

# %%
data['gender'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
plt.figure(figsize=(10,8))
plt.pie(x=data['gender'].value_counts(), autopct='%.f%%',colors = ['salmon', 'lightblue'],labels=['Male', 'Female'], rotatelabels=True)
plt.title('Gender Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
plt.hist(data['age'], bins=10, color = 'darkblue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
plt.hist(data['height'], bins=10, color = 'darkblue')
plt.xlabel('height')
plt.ylabel('Count')
plt.title('Height Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
plt.hist(data['weight'], bins=10, color = 'darkblue')
plt.xlabel('weight')
plt.ylabel('Count')
plt.title('Weight Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
plt.hist(data['ap_hi'], bins=10, color = 'darkblue')
plt.xlabel('High appetite')
plt.ylabel('Count')
plt.title('High Appetite Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
plt.hist(data['ap_lo'], bins=10, color = 'darkblue')
plt.xlabel('Low appetite')
plt.ylabel('Count')
plt.title('Low Appetite Distribution', fontweight='bold', fontsize=16)
plt.show()

# %%
data['gender'].dtype
# Out:
# dtype('O')

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data['age'])
plt.show()

# %%
data.columns.values
# Out:
# array(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'smoke'], dtype=object)

# %% [markdown]
# ### Mutivariate analysis

# %%
plt.scatter(x = data['age'], y = data['smoke'], c='C3')

# %%
df = pd.read_csv('data/real_estate_price_size.csv')
df.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
plt.scatter(x=df['size'], y = df['price'],cmap='winter')
plt.tight_layout()
plt.xlabel('Sizes')
plt.ylabel('Prices')
plt.title('Relationship between size and price', fontweight='bold', fontsize=16)
plt.show()

# %% [markdown]
# Note: Scatterplot is used to show relationship between two numerical data points.

# %%
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
### Object oriented matplotlib

fig , (ax0, ax1) = plt.subplots(ncols=1, nrows = 2, figsize=(8,6))

ax0.scatter(x=data['height'], y = data['smoke'])
ax1 = data['gender'].value_counts().plot(kind='barh')

plt.show()

# %%
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(24,12), sharey=True)

ax0.scatter(x=data['age'], y=data['smoke'])
ax0.set_xlabel('Age', fontsize=16, fontweight='bold')
ax0.set_ylabel('Smoke', fontsize=16, fontweight='bold')

ax1.scatter(x=data['weight'], y=data['smoke'])
ax1.set_xlabel('Weight', fontsize=16, fontweight='bold')

ax2.scatter(x=data['gender'], y = data['smoke'])
ax2.set_xlabel('Gender', fontsize=16, fontweight='bold')
ax2.set_ylabel('Smoke', fontsize=16, fontweight='bold')


ax3.scatter(x=data['height'], y=data['smoke'])
ax3.set_xlabel('Height', fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# #### Seaborn

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import seaborn as sns
sns.set_style('whitegrid')
print(sns.__version__)
# Out:
# 0.11.2

# %%
RE_data = pd.read_csv('data/real_estate_price_size_year.csv')

RE_data.head()
# Out:
#         price     size  year
# 0  234314.144   643.09  2015
# 1  228581.528   656.22  2009
# 2  281626.336   487.29  2018
# 3  401255.608  1504.75  2015
# 4  458674.256  1275.46  2009

# %%
RE_data.columns.values
# Out:
# array(['price', 'size', 'year'], dtype=object)

# %%
column = ['size', 'year', 'price']

df = RE_data[column]
df.head()
# Out:
#       size  year       price
# 0   643.09  2015  234314.144
# 1   656.22  2009  228581.528
# 2   487.29  2018  281626.336
# 3  1504.75  2015  401255.608
# 4  1275.46  2009  458674.256

# %%
sns.lineplot(x=df['size'],
            y=df['price'],
            hue=df['year'])
# Out:
# <AxesSubplot:xlabel='size', ylabel='price'>

# %%
sns.regplot(x = df['size'],
           y = df['price'])
# Out:
# <AxesSubplot:xlabel='size', ylabel='price'>

# %%
sns.regplot(data=df, x='size', y='price')
# Out:
# <AxesSubplot:xlabel='size', ylabel='price'>

# %%
sns.scatterplot(data=df,
           x='size',
           y='price',
           hue='year')
plt.show()

# %%
sns.lineplot(x=df['year'],
            y=df['price'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
sns.pairplot(data=df, vars=['size', 'price'], hue='year')

# %%
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
df.head()
# Out:
#       size  year       price
# 0   643.09  2015  234314.144
# 1   656.22  2009  228581.528
# 2   487.29  2018  281626.336
# 3  1504.75  2015  401255.608
# 4  1275.46  2009  458674.256

# %%
df.year.dtype
# Out:
# dtype('int64')

# %%
sns.swarmplot(data = df , x = 'year', y ='price')
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
sns.histplot(data = df, x = 'size')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x = df['size']);

# %%
sns.displot(data=df, x='size', y='price', hue ='year')

# %%
sns.jointplot(data = df, x = 'size', y='price')

# %%
sns.jointplot(data = df, x = 'year', y='price')

# %%
data.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# id
# 0    50  Female     168    62.0    110     80            1      0
# 1    55    Male     156    85.0    140     90            3      0
# 2    52    Male     165    64.0    130     70            3      0
# 3    48  Female     169    82.0    150    100            1      0
# 4    48    Male     156    56.0    100     60            1      0

# %%
sns.jointplot(data = data, x = 'age', y = 'height', hue = 'smoke')

# %%
plt.figure(figsize=(10,8))
sns.violinplot(data = data, x = "age", y = 'smoke')
# Out:
# <AxesSubplot:xlabel='age', ylabel='smoke'>

# %%
corr = data.corr()
corr
# Out:
#                   age    height    weight     ap_hi     ap_lo  cholesterol  \
# age          1.000000 -0.081456  0.053661  0.020793  0.017754     0.154386
# height      -0.081456  1.000000  0.290968  0.005488  0.006150    -0.050226
# weight       0.053661  0.290968  1.000000  0.030702  0.043710     0.141768
# ap_hi        0.020793  0.005488  0.030702  1.000000  0.016086     0.023778
# ap_lo        0.017754  0.006150  0.043710  0.016086  1.000000     0.024019
# cholesterol  0.154386 -0.050226  0.141768  0.023778  0.024019     1.000000
# smoke       -0.047884  0.187989  0.067780 -0.000922  0.005186     0.010354
#
#                 smoke
# age         -0.047884
# height       0.187989
# weight       0.067780
# ap_hi       -0.000922
# ap_lo        0.005186
# cholesterol  0.010354
# smoke        1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,
           fmt='.2f',
            annot=True,
           cmap='BuPu')
plt.show()

# %%
co = df.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(co,
           annot=True,
           fmt='.2f',
           cmap='YlGnBu')
plt.show()

# %%
sns.barplot(data = data,
           x = 'gender',
           y = 'smoke')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='smoke'>

# %%
sns.boxplot(data = data, x = 'age')
plt.show()
